# %% [markdown]
# # Import libraries

# %%
import pandas as pd

# %% [markdown]
# # Import data

# %%
df = pd.read_csv('data.csv')

# %% [markdown]
# # Read data

# %%
df['dateAdded'][:3]
# Out:
# 0    2016-03-02T11:49:34Z
# 1    2016-03-02T11:49:34Z
# 2    2016-10-14T01:58:25Z
# Name: dateAdded, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77260 entries, 0 to 77259
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 77260 non-null  object
#  1   address            77260 non-null  object
#  2   categories         77260 non-null  object
#  3   city               77260 non-null  object
#  4   cuisines           38384 non-null  object
#  5   dateAdded          77260 non-null  object
#  6   dateUpdated        77260 non-null  object
#  7   latitude           55636 non-null  float64
#  8   longitude          55636 non-null  float64
#  9   menus.category     3729 non-null   object
#  10  menus.currency     40511 non-null  object
#  11  menus.dateSeen     77260 non-null  object
#  12  menus.description  29323 non-null  object
#  13  menus.name         77260 non-null  object
#  14  name               77257 non-null  object
#  15  province           77257 non-null  object
# ...

# %%
df.describe()
# Out:
#            latitude     longitude
# count  55636.000000  55636.000000
# mean      36.694846    -98.713309
# std        4.835124     18.245857
# min      -31.986438   -159.492690
# 25%       33.668355   -117.647150
# 50%       36.047195    -96.682320
# 75%       40.588380    -82.679930
# max       61.219460    115.903696

# %%
'New York' in set(df['city'])
# Out:
# True

# %%
list(df[
    (df['city'] == 'California') & (df['name'] == 'Taco Bell')
].index)
# Out:
# [52930, 52931, 52932, 52933, 52934, 52935, 52936, 52937, 52938, 52939]

# %%
df[
    ((df['name'] == 'Taco Bell')\
    |\
    (df['city'] == 'New York'))\
    &\
    ~((df['menus.name'] == 'Volcano Taco') | (df['menus.name'] == 'Fresco Soft Taco'))
]
# Out:
#                          id          address  \
# 131    AVwc_9yCByjofQCxkdRX  322 S. Broadway
# 132    AVwc_9yCByjofQCxkdRX  322 S. Broadway
# 133    AVwc_9yCByjofQCxkdRX  322 S. Broadway
# 135    AVwc_9yCByjofQCxkdRX  322 S. Broadway
# 136    AVwc_9yCByjofQCxkdRX  322 S. Broadway
# ...                     ...              ...
# 76904  AVweZN9nByjofQCxxz4o    754 Ninth Ave
# 76905  AVweZN9nByjofQCxxz4o    754 Ninth Ave
# 76906  AVweZN9nByjofQCxxz4o    754 Ninth Ave
# 76907  AVweZN9nByjofQCxxz4o    754 Ninth Ave
# 76908  AVweZN9nByjofQCxxz4o    754 Ninth Ave
#
#                                               categories      city  \
# 131    Fast Food,Restaurants,Mexican,Breakfast,Vegeta...     Salem
# 132    Fast Food,Restaurants,Mexican,Breakfast,Vegeta...     Salem
# 133    Fast Food,Restaurants,Mexican,Breakfast,Vegeta...     Salem
# 135    Fast Food,Restaurants,Mexican,Breakfast,Vegeta...     Salem
# 136    Fast Food,Restaurants,Mexican,Breakfast,Vegeta...     Salem
# ...

# %%
df[df['menus.currency'].isna() != True]
# Out:
#                          id           address  \
# 15     AVwc_1y6kufWRAb51O6w   906 Park Ave SW
# 16     AVwc_1y6kufWRAb51O6w   906 Park Ave SW
# 17     AVwc_1y6kufWRAb51O6w   906 Park Ave SW
# 18     AVwc_2OQ_7pvs4fz1L5H  100 W Higgins Rd
# 19     AVwc_2OQ_7pvs4fz1L5H  100 W Higgins Rd
# ...                     ...               ...
# 77255  AVzRLlQNLD2H7whiWdH_     3919 24th St.
# 77256  AVzRLlQNLD2H7whiWdH_     3919 24th St.
# 77257  AVzRLlQNLD2H7whiWdH_     3919 24th St.
# 77258  AVzRLlQNLD2H7whiWdH_     3919 24th St.
# 77259  AVzRLlQNLD2H7whiWdH_     3919 24th St.
#
#                                  categories           city  \
# 15     Coffee Shop,Restaurants,Coffeehouses    Albuquerque
# 16     Coffee Shop,Restaurants,Coffeehouses    Albuquerque
# 17     Coffee Shop,Restaurants,Coffeehouses    Albuquerque
# 18                               Restaurant     Barrington
# 19                               Restaurant     Barrington
# ...

# %%
df['categories'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 77260 entries, 0 to 77259
# Series name: categories
# Non-Null Count  Dtype
# --------------  -----
# 77260 non-null  object
# dtypes: object(1)
# memory usage: 603.7+ KB

# %%
df[['categories']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77260 entries, 0 to 77259
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   categories  77260 non-null  object
# dtypes: object(1)
# memory usage: 603.7+ KB

# %%
df['city'].value_counts()[:5]
# Out:
# San Diego        1924
# Los Angeles      1603
# Chicago          1186
# San Francisco    1120
# New York         1085
# Name: city, dtype: int64

# %%
list(df[df['name'] == 'Taco Bell']['city'].value_counts()[:5].index)
# Out:
# ['Indianapolis', 'Columbus', 'Charleston', 'Tampa', 'South Lake Tahoe']

# %%
df['dateAdded'] = pd.to_datetime(df['dateAdded'])
df['dateUpdated'] = pd.to_datetime(df['dateUpdated'])

# %%
temp = df[df['dateAdded'].dt.month == 10]

# %%
temp['dateAdded'][:5].index
# Out:
# Int64Index([2, 21, 22, 23, 24], dtype='int64')

# %%
temp['dayAdded'] = temp['dateAdded'].dt.day
# Out:
# /tmp/ipykernel_261894/1528242345.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['dayAdded'] = temp['dateAdded'].dt.day

# %%
temp[['name','dayAdded']].drop_duplicates().reset_index().sort_values(by=['dayAdded','index']).index[:5]
# Out:
# Int64Index([440, 519, 1266, 1494, 1920], dtype='int64')

# %%
df.groupby(df['dateAdded'].dt.month).agg({'id': 'nunique'})
# Out:
#              id
# dateAdded
# 1           308
# 2           257
# 3          4970
# 4          3224
# 5          1141
# 6          1356
# 7           645
# 8           479
# 9           554
# 10         4716
# 11         1550
# 12          239

# %%
.drop_duplicates(subset=["Courses", "Fee"], keep=False)
# Out:
#   Cell In[20], line 1
#     .drop_duplicates(subset=["Courses", "Fee"], keep=False)
#     ^
# SyntaxError: invalid syntax

# %%
df['update_delta'] = df['dateUpdated'] - df['dateAdded']

# %%
df['update_delta']
# Out:
# 0       336 days 06:15:10
# 1       336 days 06:15:10
# 2         0 days 00:00:00
# 3        24 days 11:44:43
# 4       114 days 12:16:12
#                ...
# 77255     0 days 00:00:00
# 77256     0 days 00:00:00
# 77257     0 days 00:00:00
# 77258     0 days 00:00:00
# 77259     0 days 00:00:00
# Name: update_delta, Length: 77260, dtype: timedelta64[ns]

# %%
df.groupby('city').agg({'update_delta':'mean','latitude':'max'}).reset_index()
# Out:
#               city                update_delta   latitude
# 0        Abbeville 115 days 04:59:38.571428572  29.982108
# 1         Aberdeen     81 days 18:03:07.750000  46.975110
# 2          Abilene 206 days 19:58:38.681818182  32.453090
# 3         Abingdon    304 days 05:10:01.500000  36.712800
# 4         Abington           393 days 23:12:34  40.124851
# ...            ...                         ...        ...
# 3596       Zebulon             0 days 00:00:00  33.102090
# 3597   Zephyr Cove           105 days 12:27:04  38.984947
# 3598   Zephyrhills           329 days 22:45:36  28.271183
# 3599  Zieglerville           621 days 21:06:58  40.291611
# 3600    Zionsville    151 days 20:52:26.500000  39.954970
#
# [3601 rows x 3 columns]

# %%
df[df['city'] == 'Zephyrhills']['update_delta'].mean()
# Out:
# Timedelta('329 days 22:45:36')

# %%
df[df['categories'].str.contains('Pizza', regex=False) == True]
# Out:
#                          id                     address  \
# 0      AVwc__cikufWRAb51QjV           610 Commercial St
# 1      AVwc__cikufWRAb51QjV           610 Commercial St
# 66     AVwc_59U_7pvs4fz1Md3            3250 Kennedy Cir
# 67     AVwc_59U_7pvs4fz1Md3            3250 Kennedy Cir
# 158    AVwc_AmZkufWRAb51FxA               133 Howard St
# ...                     ...                         ...
# 76256  AVweVOBFByjofQCxxRnN          3000 N Dinuba Blvd
# 76291  AVweVXD4ByjofQCxxS7L            35 N Farview Ave
# 76507  AVweWyOEkufWRAb5CNJU  1516 E Historic Highway 66
# 76669  AVweXxalByjofQCxxnWC        1895 Washington Blvd
# 76709  AVweYFH-ByjofQCxxqHG              620 Water St S
#
#                                               categories        city  \
# 0      Restaurant Delivery Service,Restaurants,Pizza,...    Atchison
# 1      Restaurant Delivery Service,Restaurants,Pizza,...    Atchison
# 66     Pizza,Take Out Restaurants,Caterers,Restaurant...     Dubuque
# ...

# %%
df['update_delta'].dt.days.mean()
# Out:
# 326.22456639917164

# %%
df['update_delta'].dt.days.median()
# Out:
# 364.0

# %% [markdown]
# В этом задании нужно отобрать записи, у которых более 20 категорий, далее их нужно сгруппировать по провинциям и подсчитать минимальную longitude в каждой. Округлите значения longitude до 3-х знаков после запятой.
#
# Далее сохраните результирующий датафрейм в файл в формате csv с сепаратором ;. Сам датафрейм должен содержать две колонки: province и longitude

# %%
final_df = df[df['categories'].apply(lambda x: len(x.split(','))) > 20]\
    .groupby('province').agg({'longitude': 'min'}).apply(lambda x: round(x,3)).reset_index()

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   province   13 non-null     object
#  1   longitude  13 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 336.0+ bytes

# %%
final_df.head()
# Out:
#   province  longitude
# 0       AZ   -110.136
# 1       CA   -122.417
# 2       DC    -77.075
# 3    G P O    -73.990
# 4       KY    -87.455

# %%
final_df.to_csv('pandas_task_lesson_5_2023.csv', sep=";", index=False)

# %%
final_df.shape
# Out:
# (13, 2)
